# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
response = client.chat.completions.create(model='gpt-5-nano', messages=[{"role": "user", "content": "Hola, qué modelo eres?"}])

# %%
response.choices[0].message.content
# Out:
# '¡Hola! Soy ChatGPT, un modelo de lenguaje desarrollado por OpenAI, basado en la arquitectura GPT-4. Puedo ayudarte con preguntas, redacción, ideas, explicaciones y mucho más. ¿En qué te gustaría que te ayude hoy?'
